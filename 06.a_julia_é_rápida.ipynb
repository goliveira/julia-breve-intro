# %% [markdown]
# # A Julia é rápida
#
# Frequentemente, programas são executados em diferentes linguagens de programação com o propósito de comparar os desempenhos das linguagens.
# Esse tipo de comparação não é simples e pode gerar discussões.
#
# Neste notebook vamos fazer uma comparação simples entre algumas linguagens de programação, e deixar que você tire suas próprias conclusões.

# %% [markdown]
# ## A função soma
#
# Consideramos a função soma, denotada por `sum`, que é definida por
# $$
# \mathrm{sum}(a) = \sum_{j=1}^n a_j,
# $$
# onde $a = [a_1, a_2, \dots, a_j]$ é uma lista com $n$ elementos.
#
# Vamos criar uma lista com 10<sup>7</sup> elementos escolhidos aleatoriamente no intervalo $[0,1]$:

# %%
a = rand(10^7)
# Out:
# 10000000-element Array{Float64,1}:
#  0.11715580730715502
#  0.7957915888803042
#  0.2747165476852551
#  0.8085588366926777
#  0.13149217140127223
#  0.7917276693031488
#  0.3737930380736887
#  0.023832577601262894
#  0.8643517476952594
#  0.757322298171321
#  0.6355588276275586
#  0.3335625287003232
#  0.9558576669645926
#  ⋮
#  0.7935694407307472
#  0.07825962159475641
#  0.589829150705143
#  0.25597401271558806
#  0.9864131738729811
#  0.3304531564561495
#  0.7557410585468958
#  0.8772938277175746
#  0.789367081057569
#  0.5446910573561177
#  0.6658613169574465
#  0.3880315115104884

# %% [markdown]
# Calculamos a soma dos elementos de `a`:

# %%
sum(a)
# Out:
# 4.999258651770673e6

# %% [markdown]
# O resultado esperado é 0.5 * 10<sup>7</sup>, pois o valor médio de cada elemento da lista é igual a 0.5.

# %% [markdown]
# ## Medindo desempenho de formas diferentes, em linguagens diferentes

# %%
@time sum(a)
# Out:
#   0.007299 seconds (5 allocations: 176 bytes)
# 4.999258651770673e6

# %%
@time sum(a)
# Out:
#   0.007968 seconds (5 allocations: 176 bytes)
# 4.999258651770673e6

# %%
@time sum(a)
# Out:
#   0.007635 seconds (5 allocations: 176 bytes)
# 4.999258651770673e6

# %% [markdown]
# Como vemos, a macro `@time` pode fornecer resultados diferentes, portanto não é uma macro muito confiável para comparar desempenhos.
#
# O pacote `BenchmarkTools.jl` fornece um método simples e preciso de fazer comparações.

# %%
using Pkg
Pkg.add("BenchmarkTools")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
using BenchmarkTools

# %% [markdown]
# ## 1. C
#
# A linguagem C é considerada uma linguagem difícil para os humanos e simples para as máquinas.
#
# Em uma sessão da Julia, podemos inserir um programa em C, compilá-lo e executá-lo:

# %%
using Libdl
C_code = """
#include <stddef.h>
double c_sum(size_t n, double *X) {
    double s = 0.0;
    for (size_t i = 0; i < n; ++i) {
        s += X[i];
    }
    return s;
}
"""

const Clib = tempname()  # Cria um arquivo temporário

# Compila para uma biblioteca compartilhada passando
# o código C_code para o compilador gcc (só funciona
# se o gcc estiver instalado):

open(`gcc -fPIC -O3 -msse3 -xc -shared -o $(Clib * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# Define uma função em Julia que chama a função do C
c_sum(X::Array{Float64}) = ccall(("c_sum", Clib), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum (generic function with 1 method)

# %%
c_sum(a)
# Out:
# 4.999258651770628e6

# %%
c_sum(a) ≈ sum(a)  # Digite \approx e tecle <TAB> para obter o símbolo ≈
# Out:
# true

# %%
c_sum(a) - sum(a)
# Out:
# -4.470348358154297e-8

# %%
≈ # é uma abreviação (alias) para a função `isapprox`
# Out:
# isapprox (generic function with 8 methods)

# %%
?isapprox
# Out:
# search: isapprox
#   isapprox(x, y; rtol::Real=atol>0 ? 0 : √eps, atol::Real=0, nans::Bool=false, norm::Function)
#
#   Inexact equality comparison: true if norm(x-y) <= max(atol,
#   rtol*max(norm(x), norm(y))). The default atol is zero and the default rtol
#   depends on the types of x and y. The keyword argument nans determines
#   whether or not NaN values are considered equal (defaults to false).
#
#   For real or complex floating-point values, if an atol > 0 is not specified,
#   rtol defaults to the square root of eps of the type of x or y, whichever is
#   bigger (least precise). This corresponds to requiring equality of about half
#   of the significand digits. Otherwise, e.g. for integer arguments or if an
#   atol > 0 is supplied, rtol defaults to zero.
#
#   x and y may also be arrays of numbers, in which case norm defaults to
#   vecnorm but may be changed by passing a norm::Function keyword argument.
#   (For numbers, norm is the same thing as abs.) When x and y are arrays, if
#   norm(x-y) is not finite (i.e. ±Inf or NaN), the comparison falls back to
#   checking whether all elements of x and y are approximately equal
#   component-wise.
#
#   The binary operator ≈ is equivalent to isapprox with the default arguments,
#   and x ≉ y is equivalent to !isapprox(x,y).
#
#   Note that x ≈ 0 (i.e., comparing to zero with the default tolerances) is
#   equivalent to x == 0 since the default atol is 0. In such cases, you should
#   either supply an appropriate atol (or use norm(x) ≤ atol) or rearrange your
#   code (e.g. use x ≈ y rather than x - y ≈ 0). It is not possible to pick a
#   nonzero atol automatically because it depends on the overall scaling (the
#   "units") of your problem: for example, in x - y ≈ 0, atol=1e-9 is an
#   absurdly small tolerance if x is the radius of the Earth
#   (https://en.wikipedia.org/wiki/Earth_radius) in meters, but an absurdly
#   large tolerance if x is the radius of a Hydrogen atom
#   (https://en.wikipedia.org/wiki/Bohr_radius) in meters.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> 0.1 ≈ (0.1 - 1e-10)
#   true
#
#   julia> isapprox(10, 11; atol = 2)
#   true
#
#   julia> isapprox([10.0^9, 1.0], [10.0^9, 2.0])
#   true
#
#   julia> 1e-10 ≈ 0
#   false
#
#   julia> isapprox(1e-10, 0, atol=1e-8)
#   true

# %% [markdown]
# Agora podemos medir o desempenho do código C diretamente da sessão Julia.

# %%
c_bench = @benchmark c_sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     12.177 ms (0.00% GC)
#   median time:      12.309 ms (0.00% GC)
#   mean time:        12.840 ms (0.00% GC)
#   maximum time:     21.492 ms (0.00% GC)
#   --------------
#   samples:          390
#   evals/sample:     1

# %%
println("C: O tempo mais rápido foi $(minimum(c_bench.times) / 1e6) msec")
# Out:
# C: O tempo mais rápido foi 12.176981 msec

# %%
d = Dict()
d["C"] = minimum(c_bench.times) / 1e6  # em milisegundos
d
# Out:
# Dict{Any,Any} with 1 entry:
#   "C" => 12.177

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
using Statistics
t = c_bench.times / 1e6 # tempos em milisegundos
m, σ = minimum(t), std(t)

histogram(t, bins=500,
    xlim=(m - 0.01, m + σ),
    xlabel="milisegundos", ylabel="Frequência", label="")

# %% [markdown]
# ## 2. C com -ffast-math
#
# Agora, vamos permitir que o C otimize suas operações de ponto flutuante.
# Dessa forma, ele vai vetorizar suas instruções usando [SIMD](https://en.wikipedia.org/wiki/SIMD) (single instruction, multiple data).

# %%
const Clib_fastmath = tempname()

# Como acima mas agora com a opção -ffast-math
open(`gcc -fPIC -O3 -msse3 -xc -shared -ffast-math -o $(Clib_fastmath * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# Define uma função em Julia que chama a função em C
c_sum_fastmath(X::Array{Float64}) = ccall(("c_sum", Clib_fastmath), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum_fastmath (generic function with 1 method)

# %%
c_fastmath_bench = @benchmark $c_sum_fastmath($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     6.250 ms (0.00% GC)
#   median time:      6.435 ms (0.00% GC)
#   mean time:        6.643 ms (0.00% GC)
#   maximum time:     16.570 ms (0.00% GC)
#   --------------
#   samples:          752
#   evals/sample:     1

# %%
d["C com -ffast-math"] = minimum(c_fastmath_bench.times) / 1e6  # em milisegundos
# Out:
# 6.250245

# %% [markdown]
# ## 3. Python
#
# O pacote `PyCall` fornece uma interface entre a Julia e o Python:

# %%
Pkg.add("PyCall")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
using PyCall

# %%
# Importa a função "sum" do Python
pysum = pybuiltin("sum")
# Out:
# PyObject <built-in function sum>

# %%
pysum(a)
# Out:
# 4.999258651770628e6

# %%
pysum(a) ≈ sum(a)
# Out:
# true

# %%
py_list_bench = @benchmark $pysum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  368 bytes
#   allocs estimate:  8
#   --------------
#   minimum time:     715.783 ms (0.00% GC)
#   median time:      745.163 ms (0.00% GC)
#   mean time:        740.274 ms (0.00% GC)
#   maximum time:     775.898 ms (0.00% GC)
#   --------------
#   samples:          7
#   evals/sample:     1

# %%
d["Python"] = minimum(py_list_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 3 entries:
#   "C com -ffast-math" => 6.25024
#   "C"                 => 12.177
#   "Python"            => 715.783

# %% [markdown]
# ## 4. Python `numpy`
#
# A biblioteca `numpy` do Python é escrita em C e também utiliza SIMD.
# Essa biblioteca pode ser instalada na Julia da seguinte forma:

# %%
Pkg.add("Conda")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
using Conda

# %%
numpy_sum = pyimport("numpy")["sum"]

py_numpy_bench = @benchmark $numpy_sum($a)
# Out:
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = top-level scope at In[31]:1
# └ @ Core In[31]:1
# BenchmarkTools.Trial:
#   memory estimate:  368 bytes
#   allocs estimate:  8
#   --------------
#   minimum time:     5.674 ms (0.00% GC)
#   median time:      5.785 ms (0.00% GC)
#   mean time:        5.816 ms (0.00% GC)
#   maximum time:     7.488 ms (0.00% GC)
#   --------------
#   samples:          859
#   evals/sample:     1

# %%
numpy_sum(a)
# Out:
# 4.999258651770672e6

# %%
numpy_sum(a) ≈ sum(a)
# Out:
# true

# %%
d["Python numpy"] = minimum(py_numpy_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 4 entries:
#   "C com -ffast-math" => 6.25024
#   "C"                 => 12.177
#   "Python numpy"      => 5.67387
#   "Python"            => 715.783

# %% [markdown]
# ## 5. Python (escrito à mão)

# %%
py"""
def py_sum(A):
    s = 0.0
    for a in A:
        s += a
    return s
"""

sum_py = py"py_sum"
# Out:
# PyObject <function py_sum at 0x7f37cd9af0d0>

# %%
py_hand = @benchmark $sum_py($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  368 bytes
#   allocs estimate:  8
#   --------------
#   minimum time:     823.590 ms (0.00% GC)
#   median time:      855.354 ms (0.00% GC)
#   mean time:        853.274 ms (0.00% GC)
#   maximum time:     885.896 ms (0.00% GC)
#   --------------
#   samples:          6
#   evals/sample:     1

# %%
sum_py(a)
# Out:
# 4.999258651770628e6

# %%
sum_py(a) ≈ sum(a)
# Out:
# true

# %%
d["Python escrito à mão"] = minimum(py_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 5 entries:
#   "C com -ffast-math"    => 6.25024
#   "Python escrito à mão" => 823.59
#   "C"                    => 12.177
#   "Python numpy"         => 5.67387
#   "Python"               => 715.783

# %% [markdown]
# ## 6. Julia
#
# Em Julia, a função `sum` é escrita em Julia, não em C.

# %%
@which sum(a)
# Out:
# sum(a::AbstractArray) in Base at reducedim.jl:648

# %%
j_bench = @benchmark sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     5.887 ms (0.00% GC)
#   median time:      6.084 ms (0.00% GC)
#   mean time:        6.487 ms (0.00% GC)
#   maximum time:     10.784 ms (0.00% GC)
#   --------------
#   samples:          770
#   evals/sample:     1

# %%
d["Julia"] = minimum(j_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 6 entries:
#   "C com -ffast-math"    => 6.25024
#   "Python escrito à mão" => 823.59
#   "C"                    => 12.177
#   "Python numpy"         => 5.67387
#   "Julia"                => 5.88686
#   "Python"               => 715.783

# %% [markdown]
# ## 7. Julia (escrito à mão)

# %%
function mysum(A)   
    s = 0.0 # s = zero(eltype(a))
    for a in A
        s += a
    end
    s
end
# Out:
# mysum (generic function with 1 method)

# %%
j_bench_hand = @benchmark mysum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     12.178 ms (0.00% GC)
#   median time:      12.206 ms (0.00% GC)
#   mean time:        12.227 ms (0.00% GC)
#   maximum time:     13.490 ms (0.00% GC)
#   --------------
#   samples:          409
#   evals/sample:     1

# %%
d["Julia escrito à mão"] = minimum(j_bench_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 7 entries:
#   "C com -ffast-math"    => 6.25024
#   "Python escrito à mão" => 823.59
#   "C"                    => 12.177
#   "Python numpy"         => 5.67387
#   "Julia escrito à mão"  => 12.1778
#   "Julia"                => 5.88686
#   "Python"               => 715.783

# %% [markdown]
# ## 8. Julia (escrito à mão com SIMD)

# %%
function mysum_simd(A)   
    s = 0.0 # s = zero(eltype(A))
    @simd for a in A
        s += a
    end
    s
end
# Out:
# mysum_simd (generic function with 1 method)

# %%
j_bench_hand_simd = @benchmark mysum_simd($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     5.829 ms (0.00% GC)
#   median time:      6.093 ms (0.00% GC)
#   mean time:        6.928 ms (0.00% GC)
#   maximum time:     12.704 ms (0.00% GC)
#   --------------
#   samples:          721
#   evals/sample:     1

# %%
mysum_simd(a)
# Out:
# 4.999258651770635e6

# %%
d["Julia escrito à mão com SIMD"] = minimum(j_bench_hand_simd.times) / 1e6
d
# Out:
# Dict{Any,Any} with 8 entries:
#   "Julia escrito à mão com SIMD" => 5.82893
#   "C com -ffast-math"            => 6.25024
#   "Python escrito à mão"         => 823.59
#   "C"                            => 12.177
#   "Python numpy"                 => 5.67387
#   "Julia escrito à mão"          => 12.1778
#   "Julia"                        => 5.88686
#   "Python"                       => 715.783

# %% [markdown]
# ## Em resumo

# %%
for (key, value) in sort(collect(d), by=last)
    println(rpad(key, 30, "."), lpad(round(value; digits=1), 6, "."))
end
# Out:
# Python numpy.....................5.7
# Julia escrito à mão com SIMD.....5.8
# Julia............................5.9
# C com -ffast-math................6.3
# C...............................12.2
# Julia escrito à mão.............12.2
# Python.........................715.8
# Python escrito à mão...........823.6
